# %%
latex(integrate(sin(x^5),x))
# Out:
# -\frac{{\left({\left(\sqrt{5} - 1\right)} {\left(\Gamma\left(\frac{1}{5}, i \, x^{5}\right) + \Gamma\left(\frac{1}{5}, -i \, x^{5}\right)\right)} + \sqrt{2 \, \sqrt{5} + 10} {\left(i \, \Gamma\left(\frac{1}{5}, i \, x^{5}\right) - i \, \Gamma\left(\frac{1}{5}, -i \, x^{5}\right)\right)}\right)} x}{40 \, {\left(x^{5}\right)}^{\frac{1}{5}}}

# %% [markdown]
# $$
# -\frac{{\left({\left(\sqrt{5} - 1\right)} {\left(\Gamma\left(\frac{1}{5}, i \, x^{5}\right) + \Gamma\left(\frac{1}{5}, -i \, x^{5}\right)\right)} + \sqrt{2 \, \sqrt{5} + 10} {\left(i \, \Gamma\left(\frac{1}{5}, i \, x^{5}\right) - i \, \Gamma\left(\frac{1}{5}, -i \, x^{5}\right)\right)}\right)} x}{40 \, {\left(x^{5}\right)}^{\frac{1}{5}}}
# $$

# %%
show(integrate(sin(x^5),x))
# Out:
# -1/40*((sqrt(5) - 1)*(gamma(1/5, I*x^5) + gamma(1/5, -I*x^5)) + sqrt(2*sqrt(5) + 10)*(I*gamma(1/5, I*x^5) - I*gamma(1/5, -I*x^5)))*x/(x^5)^(1/5)

# %%
v = [(0,0,0)]
for i in range(1000):
    v.append([a+random()-.5 for a in v[-1]])
line3d(v, color='red', thickness=3, spin=3)
# Out:
# Graphics3d Object

# %%
show(random_matrix(QQ,15)^(-1))
# Out:
# [  21070628/29244031   13659792/29244031   55422501/29244031  -57282946/29244031   91769350/29244031    -285480/29244031   37480507/29244031 -219907292/29244031    7814444/29244031    9003156/29244031  109853125/29244031   60736379/29244031   -6479690/29244031   84966027/29244031     732606/29244031]
# [  -3651700/29244031  -14257706/29244031  -35069340/29244031   35681958/29244031  -58958423/29244031    2738070/29244031  -18664997/29244031  121556554/29244031   -9343728/29244031   -3854800/29244031  -68674041/29244031  -34351204/29244031    -710654/29244031  -48682465/29244031   -2767128/29244031]
# [  -9367270/29244031   -5573973/29244031   -4901881/29244031   10688463/29244031  -33091125/58488062   -1341861/29244031  -19013677/58488062   38760137/29244031     286970/29244031   -7544219/29244031  -29639335/58488062   -9367256/29244031    1924784/29244031  -21220015/58488062    4407870/29244031]
# ...
